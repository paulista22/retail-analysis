# %% [markdown]
# # 🧾 Exploratory Data Analysis (EDA) - Order Reviews
#
# This notebook performs a complete EDA on the 'Order Reviews' dataset, including:
#
# - General overview of the dataset
# - Basic data cleaning
# - Summary statistics
# - Visualization of numerical and categorical variables

# %% [markdown]
# Postgre sql connection set up

# %%
import psycopg2
try:
    conn = psycopg2.connect(
        host="localhost",
        database="project",
        user="postgres",
        password="vender2299",
        client_encoding='WIN1252')
    cur = conn.cursor()
    print("Successfully connected to PostgreSQL!")

except psycopg2.Error as e:
    print(f"Error connecting to PostgreSQL: {e}")
# Out:
# Successfully connected to PostgreSQL!

# %% [markdown]
# Using SQLAlchemy to Load Data from PostgreSQL into a Pandas DataFrame

# %%
import pandas as pd
from sqlalchemy import create_engine

engine = create_engine('postgresql://postgres:vender2299@localhost:5432/project')

query = "SELECT * FROM order_reviews_clean"
order_reviews = pd.read_sql(query, con=engine)

print(order_reviews.head())
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title_en  \
# 0           4.0              No comment
# 1           5.0              No comment
# 2           5.0              No comment
# 3           5.0              No comment
# 4           5.0              No comment
#
#                            review_comment_message_en review_creation_date  \
# 0                                         no comment           2024-01-18
# 1                                               None           2024-03-10
# ...

# %% [markdown]
# Using SQLAlchemy to Load Data from PostgreSQL into a Pandas DataFrame

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# 🔍 General overview
print("🔹 Dimensions:", order_reviews.shape)
print("\n🔹 Columns:")
print(order_reviews.columns)
print("\n🔹 Data types:")
print(order_reviews.dtypes)
print("\n🔹 First 5 rows:")
print(order_reviews.head())

# 🔁 Duplicates
duplicates = order_reviews.duplicated()
print("\n🔁 Duplicate rows:", duplicates.sum())
if duplicates.sum() > 0:
    print("\n🔍 Showing duplicates:")
    display(order_reviews[duplicates])

# 🧼 Missing values
print("\n🔹 Missing values per column:")
print(order_reviews.isnull().sum())

# 📊 Basic statistics
print("\n📈 Numerical statistics:")
print(order_reviews.describe())

# 🧠 Separate columns by type
num_cols = order_reviews.select_dtypes(include=np.number).columns
cat_cols = order_reviews.select_dtypes(include='object').columns

print("\n🔸 Numerical columns:", list(num_cols))
print("🔸 Categorical columns:", list(cat_cols))

# 🎯 Unique values in categorical columns
for col in cat_cols:
    print(f"\n🎲 {col} - Unique values:")
    print(order_reviews[col].value_counts())

# 📉 Histograms for numerical columns
order_reviews[num_cols].hist(bins=30, figsize=(12, 10))
plt.tight_layout()
plt.show()

# 📦 Boxplots for numerical columns
for col in num_cols:
    plt.figure(figsize=(6, 4))
    sns.boxplot(x=order_reviews[col])
    plt.title(f'Outliers - {col}')
    plt.show()
# Out:
# 🔹 Dimensions: (99329, 7)
#
# 🔹 Columns:
# Index(['review_id', 'order_id', 'review_score', 'review_comment_title_en',
#        'review_comment_message_en', 'review_creation_date',
#        'review_answer_timestamp'],
#       dtype='object')
#
# 🔹 Data types:
# review_id                            object
# order_id                             object
# review_score                        float64
# review_comment_title_en              object
# review_comment_message_en            object
# review_creation_date                 object
# review_answer_timestamp      datetime64[ns]
# dtype: object
#
# 🔹 First 5 rows:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# ...
